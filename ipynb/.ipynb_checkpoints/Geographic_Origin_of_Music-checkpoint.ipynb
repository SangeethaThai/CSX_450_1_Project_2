# %% [markdown]
# # Predicting the Geographic Origin of Music

# %% [markdown]
# ### The size of the dataset
# The dataset contains 1059 rows representing music tracks and 70 columns. Of the 70 columns, 68 represent features of music, and 2 represent lattitude and longitude, the geographical origin of the music track.
#
# The size of the dataset is 678KB
#
# The memory footprint is 601KB

# %% [markdown]
# ### The types of the data
#
#    - float with 6 digits of precision for all music features and
#    - float with 2 digits of precision for lattitude and longitude.

# %% [markdown]
# ### Read data from csv file ../data/default_features_1059_tracks.txt

# %%
df <- read.csv("../data/default_features_1059_tracks.txt", header = FALSE)

# %%
colnames(df) <- c(c(paste("Feature", c(1:68), "")), c("Latitude", "Longitude"))

head(df)
# Out:
#   Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  Feature 7
# 1  7.161286   7.835325   2.911583  0.984049   -1.499546  -2.094097   0.576000
# 2  0.225763  -0.094169  -0.603646  0.497745    0.874036   0.290280  -0.077659
# 3 -0.692525  -0.517801  -0.788035  1.214351   -0.907214   0.880213   0.406899
# 4 -0.735562  -0.684055   2.058215  0.716328   -0.011393   0.805396   1.497982
# 5  0.570272   0.273157  -0.279214  0.083456    1.049331  -0.869295  -0.265858
# 6  0.059217   0.034537  -0.703441  0.188652   -0.270353   1.420526   0.467766
#   Feature 8  Feature 9  Feature 10  ⋯ Feature 61  Feature 62  Feature 63
# 1 -1.205671   1.849122  -0.425598   ⋯ -1.504263    0.351267   -1.018726
# 2 -0.887385   0.432062  -0.093963   ⋯ -0.495712   -0.465077   -0.157861
# 3 -0.694895  -0.901869  -1.701574   ⋯ -0.637167    0.147260    0.217914
# 4  0.114752   0.692847   0.052377   ⋯ -0.178325   -0.065059   -0.724247
# 5 -0.401676  -0.872639   1.147483   ⋯ -0.919463   -0.667912   -0.820172
# 6  0.209594  -0.496505   1.239908   ⋯  0.501017   -0.354263    0.445184
#   Feature 64  Feature 65  Feature 66  Feature 67  Feature 68  Latitude
# 1 -0.174878   -1.089543   -0.668840   -0.914772   -0.836250   -15.75
# 2 -0.157189    0.380951    1.088478   -0.123595    1.391141    14.91
# 3  2.718442    0.972919    2.081069    1.375763    1.063847    12.65
# 4 -1.020687   -0.751380   -0.385005   -0.012326   -0.392197     9.03
# 5 -0.190488    0.306974    0.119658    0.271838    1.289783    34.03
# 6  0.060328    0.075293   -0.170387   -0.506187   -0.008470    12.65
#   Longitude
# 1 -47.95
# 2 -23.51
# 3  -8.00
# 4  38.74
# 5  -6.85
# 6  -8.00

# %% [markdown]
# ### Throw away missing data records

# %%
df <- na.omit(df)

# %% [markdown]
# ### Generate Countries from Latitude, Longitude so we can do a Classification by Countries

# %%
location <- df[,69:70]
getCountry<-function(lat,lon){
  library(httr)
  address<-paste0("http://api.geonames.org/countryCode?lat=",lat,"&lng=",lon,"&username=sangeethathai")
  resp<-httr::GET(url = address, config = list(type = "JSON"))
  country<-content(resp, "text", encoding = "UTF-8")
  country<-sub("\n","",country)
  country<-sub("\r","",country)
  return(country)
}

# %%
Countries <- mapply(getCountry,location[,1],location[,2])

# %% [markdown]
# ### Set Countries as RowNames

# %%
df$Country <- Countries

# %%
head(df)
# Out:
#   Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  Feature 7
# 1  7.161286   7.835325   2.911583  0.984049   -1.499546  -2.094097   0.576000
# 2  0.225763  -0.094169  -0.603646  0.497745    0.874036   0.290280  -0.077659
# 3 -0.692525  -0.517801  -0.788035  1.214351   -0.907214   0.880213   0.406899
# 4 -0.735562  -0.684055   2.058215  0.716328   -0.011393   0.805396   1.497982
# 5  0.570272   0.273157  -0.279214  0.083456    1.049331  -0.869295  -0.265858
# 6  0.059217   0.034537  -0.703441  0.188652   -0.270353   1.420526   0.467766
#   Feature 8  Feature 9  Feature 10  ⋯ Feature 62  Feature 63  Feature 64
# 1 -1.205671   1.849122  -0.425598   ⋯  0.351267   -1.018726   -0.174878
# 2 -0.887385   0.432062  -0.093963   ⋯ -0.465077   -0.157861   -0.157189
# 3 -0.694895  -0.901869  -1.701574   ⋯  0.147260    0.217914    2.718442
# 4  0.114752   0.692847   0.052377   ⋯ -0.065059   -0.724247   -1.020687
# 5 -0.401676  -0.872639   1.147483   ⋯ -0.667912   -0.820172   -0.190488
# 6  0.209594  -0.496505   1.239908   ⋯ -0.354263    0.445184    0.060328
#   Feature 65  Feature 66  Feature 67  Feature 68  Latitude Longitude
# 1 -1.089543   -0.668840   -0.914772   -0.836250   -15.75   -47.95
# 2  0.380951    1.088478   -0.123595    1.391141    14.91   -23.51
# 3  0.972919    2.081069    1.375763    1.063847    12.65    -8.00
# 4 -0.751380   -0.385005   -0.012326   -0.392197     9.03    38.74
# 5  0.306974    0.119658    0.271838    1.289783    34.03    -6.85
# 6  0.075293   -0.170387   -0.506187   -0.008470    12.65    -8.00
#   Country
# 1 BR
# 2 CV
# 3 ML
# 4 ET
# 5 ERR:15:no country code found
# 6 ML

# %% [markdown]
# ### Filter out records where Country code was not found

# %%
df <- df[df$Country !=  "ERR:15:no country code found",]

# %% [markdown]
# ### Throw away Latitude/Longitude as we no longer need them

# %%
df$Latitude <- NULL
df$Longitude <- NULL

dim(df)
head(df)
# Out:
# [1] 1002   69
#   Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  Feature 7
# 1  7.161286   7.835325   2.911583  0.984049   -1.499546  -2.094097   0.576000
# 2  0.225763  -0.094169  -0.603646  0.497745    0.874036   0.290280  -0.077659
# 3 -0.692525  -0.517801  -0.788035  1.214351   -0.907214   0.880213   0.406899
# 4 -0.735562  -0.684055   2.058215  0.716328   -0.011393   0.805396   1.497982
# 6  0.059217   0.034537  -0.703441  0.188652   -0.270353   1.420526   0.467766
# 7 -0.280628  -0.310082  -0.756816  0.839033   -0.196670   1.153469  -0.473974
#   Feature 8  Feature 9  Feature 10  ⋯ Feature 60  Feature 61  Feature 62
# 1 -1.205671   1.849122  -0.425598   ⋯ -0.043610   -1.504263    0.351267
# 2 -0.887385   0.432062  -0.093963   ⋯ -0.947933   -0.495712   -0.465077
# 3 -0.694895  -0.901869  -1.701574   ⋯ -0.556109   -0.637167    0.147260
# 4  0.114752   0.692847   0.052377   ⋯  0.166616   -0.178325   -0.065059
# 6  0.209594  -0.496505   1.239908   ⋯  1.428818    0.501017   -0.354263
# 7  1.491603  -0.105328   1.365001   ⋯  1.340570    0.473937   -0.433843
#   Feature 63  Feature 64  Feature 65  Feature 66  Feature 67  Feature 68
# 1 -1.018726   -0.174878   -1.089543   -0.668840   -0.914772   -0.836250
# 2 -0.157861   -0.157189    0.380951    1.088478   -0.123595    1.391141
# 3  0.217914    2.718442    0.972919    2.081069    1.375763    1.063847
# 4 -0.724247   -1.020687   -0.751380   -0.385005   -0.012326   -0.392197
# 6  0.445184    0.060328    0.075293   -0.170387   -0.506187   -0.008470
# 7  0.813016    1.101685   -0.936123   -0.280096   -0.995073   -0.872726
#   Country
# 1 BR
# 2 CV
# 3 ML
# 4 ET
# 6 ML
# 7 ML

# %% [markdown]
# ### Summary data

# %%
summary(df)
# Out:
#    Feature 1          Feature 2          Feature 3          Feature 4
#  Min.   :-1.52946   Min.   :-1.47656   Min.   :-1.13367   Min.   :-3.2227
#  1st Qu.:-0.60651   1st Qu.:-0.62063   1st Qu.:-0.61414   1st Qu.:-0.6643
#  Median :-0.18448   Median :-0.21071   Median :-0.31077   Median :-0.1572
#  Mean   :-0.01958   Mean   :-0.02381   Mean   :-0.04888   Mean   :-0.0528
#  3rd Qu.: 0.30545   3rd Qu.: 0.30634   3rd Qu.: 0.15656   3rd Qu.: 0.4587
#  Max.   : 9.43950   Max.   :10.71930   Max.   : 6.15785   Max.   : 5.9269
#    Feature 5          Feature 6           Feature 7          Feature 8
#  Min.   :-3.38639   Min.   :-3.565809   Min.   :-4.29193   Min.   :-5.287408
#  1st Qu.:-0.60139   1st Qu.:-0.622794   1st Qu.:-0.60976   1st Qu.:-0.557304
#  Median : 0.15088   Median : 0.014802   Median : 0.05224   Median : 0.038592
#  Mean   : 0.01536   Mean   : 0.004931   Mean   :-0.01515   Mean   :-0.003774
#  3rd Qu.: 0.69349   3rd Qu.: 0.661854   3rd Qu.: 0.64781   3rd Qu.: 0.547444
#  Max.   : 2.28023   Max.   : 2.897006   Max.   : 2.72013   Max.   : 3.127494
#    Feature 9         Feature 10          Feature 11          Feature 12
#  Min.   :-5.28154   Min.   :-6.856486   Min.   :-5.689593   Min.   :-5.08850
#  1st Qu.:-0.50167   1st Qu.:-0.445318   1st Qu.:-0.508371   1st Qu.:-0.45145
#  Median : 0.07809   Median : 0.104680   Median : 0.068564   Median : 0.05708
#  Mean   :-0.03086   Mean   :-0.007681   Mean   : 0.003259   Mean   :-0.01937
#  3rd Qu.: 0.58773   3rd Qu.: 0.569829   3rd Qu.: 0.588457   3rd Qu.: 0.57359
#  Max.   : 2.42589   Max.   : 3.492393   Max.   : 5.912188   Max.   : 4.14348
#   Feature 13         Feature 14         Feature 15         Feature 16
#  Min.   :-4.00976   Min.   :-5.70306   Min.   :-4.16889   Min.   :-4.23772
#  1st Qu.:-0.54487   1st Qu.:-0.57286   1st Qu.:-0.54876   1st Qu.:-0.53818
#  Median : 0.07563   Median : 0.00158   Median :-0.03919   Median :-0.00507
#  Mean   :-0.01686   Mean   :-0.02370   Mean   :-0.03084   Mean   :-0.04678
#  3rd Qu.: 0.58010   3rd Qu.: 0.57097   3rd Qu.: 0.52609   3rd Qu.: 0.54198
#  Max.   : 3.98408   Max.   : 7.03240   Max.   : 6.17769   Max.   : 5.79859
#   Feature 17          Feature 18         Feature 19         Feature 20
#  Min.   :-5.465138   Min.   :-1.29710   Min.   :-1.35472   Min.   :-1.1078
#  1st Qu.:-0.539304   1st Qu.:-0.62828   1st Qu.:-0.57525   1st Qu.:-0.7397
#  Median :-0.011334   Median :-0.27186   Median :-0.23959   Median :-0.4546
#  Mean   : 0.006788   Mean   :-0.04027   Mean   :-0.04744   Mean   :-0.0579
#  3rd Qu.: 0.542598   3rd Qu.: 0.24940   3rd Qu.: 0.23888   3rd Qu.: 0.3189
#  Max.   : 4.749992   Max.   : 9.03831   Max.   : 9.71256   Max.   : 3.4689
#   Feature 21         Feature 22         Feature 23         Feature 24
#  Min.   :-1.57262   Min.   :-2.04678   Min.   :-2.49650   Min.   :-2.44943
#  1st Qu.:-0.70273   1st Qu.:-0.73543   1st Qu.:-0.79378   1st Qu.:-0.75571
#  Median :-0.22482   Median :-0.10741   Median :-0.17281   Median :-0.19888
#  Mean   :-0.02346   Mean   :-0.05763   Mean   :-0.04929   Mean   :-0.04452
#  3rd Qu.: 0.38348   3rd Qu.: 0.45647   3rd Qu.: 0.54752   3rd Qu.: 0.47081
#  Max.   : 7.53891   Max.   : 3.77390   Max.   : 5.31114   Max.   : 6.05201
#   Feature 25         Feature 26         Feature 27         Feature 28
#  Min.   :-3.09288   Min.   :-3.20077   Min.   :-2.87216   Min.   :-3.242499
#  1st Qu.:-0.66363   1st Qu.:-0.65846   1st Qu.:-0.66157   1st Qu.:-0.595603
#  Median :-0.22952   Median :-0.13809   Median :-0.11077   Median :-0.100068
#  Mean   :-0.02969   Mean   :-0.00574   Mean   :-0.01003   Mean   :-0.004864
#  3rd Qu.: 0.39721   3rd Qu.: 0.53524   3rd Qu.: 0.52320   3rd Qu.: 0.497086
#  Max.   : 4.69118   Max.   : 4.20378   Max.   : 6.60086   Max.   : 6.321049
#   Feature 29          Feature 30         Feature 31          Feature 32
#  Min.   :-3.213401   Min.   :-3.06845   Min.   :-2.589081   Min.   :-2.516073
#  1st Qu.:-0.611145   1st Qu.:-0.62790   1st Qu.:-0.614866   1st Qu.:-0.619384
#  Median :-0.082084   Median :-0.07345   Median :-0.149936   Median :-0.165572
#  Mean   :-0.004993   Mean   :-0.01394   Mean   : 0.002389   Mean   : 0.000839
#  3rd Qu.: 0.462652   3rd Qu.: 0.48641   3rd Qu.: 0.465048   3rd Qu.: 0.410569
#  Max.   : 7.117363   Max.   : 5.53951   Max.   : 4.892820   Max.   : 4.641688
#   Feature 33          Feature 34          Feature 35         Feature 36
#  Min.   :-2.511380   Min.   :-2.430633   Min.   :-0.98400   Min.   :-1.41352
#  1st Qu.:-0.622088   1st Qu.:-0.622058   1st Qu.:-0.60148   1st Qu.:-0.91629
#  Median :-0.183212   Median :-0.190547   Median :-0.34727   Median :-0.10656
#  Mean   : 0.003519   Mean   :-0.001506   Mean   :-0.05629   Mean   :-0.06149
#  3rd Qu.: 0.368660   3rd Qu.: 0.382995   3rd Qu.: 0.10768   3rd Qu.: 0.41188
#  Max.   : 5.179880   Max.   : 5.381346   Max.   : 6.17687   Max.   : 4.60297
#   Feature 37         Feature 38          Feature 39         Feature 40
#  Min.   :-1.93521   Min.   :-1.602092   Min.   :-1.89428   Min.   :-1.85650
#  1st Qu.:-0.72127   1st Qu.:-0.704500   1st Qu.:-0.70781   1st Qu.:-0.66129
#  Median :-0.11518   Median :-0.057719   Median :-0.15670   Median :-0.15678
#  Mean   :-0.02593   Mean   : 0.001871   Mean   :-0.00256   Mean   :-0.01982
#  3rd Qu.: 0.53080   3rd Qu.: 0.344558   3rd Qu.: 0.48570   3rd Qu.: 0.44747
#  Max.   : 4.22820   Max.   : 7.915519   Max.   : 4.01000   Max.   : 7.09664
#   Feature 41        Feature 42         Feature 43         Feature 44
#  Min.   :-1.5720   Min.   :-1.54581   Min.   :-1.55771   Min.   :-1.44102
#  1st Qu.:-0.7769   1st Qu.:-0.70978   1st Qu.:-0.67181   1st Qu.:-0.62420
#  Median :-0.1900   Median :-0.24890   Median :-0.21910   Median :-0.22776
#  Mean   :-0.0152   Mean   : 0.01434   Mean   : 0.02741   Mean   : 0.03915
#  3rd Qu.: 0.5842   3rd Qu.: 0.44614   3rd Qu.: 0.42782   3rd Qu.: 0.41386
#  Max.   : 5.4411   Max.   : 5.59996   Max.   : 5.70805   Max.   : 7.45406
#   Feature 45         Feature 46         Feature 47         Feature 48
#  Min.   :-1.40071   Min.   :-1.62121   Min.   :-1.46147   Min.   :-1.2598
#  1st Qu.:-0.65594   1st Qu.:-0.65070   1st Qu.:-0.64368   1st Qu.:-0.6193
#  Median :-0.20743   Median :-0.21533   Median :-0.20161   Median :-0.2281
#  Mean   : 0.03245   Mean   : 0.03805   Mean   : 0.03674   Mean   : 0.0419
#  3rd Qu.: 0.44823   3rd Qu.: 0.42132   3rd Qu.: 0.44508   3rd Qu.: 0.3775
#  Max.   : 6.68869   Max.   : 5.44257   Max.   : 8.40837   Max.   : 8.1731
#   Feature 49         Feature 50         Feature 51         Feature 52
#  Min.   :-1.31120   Min.   :-1.37628   Min.   :-1.37567   Min.   :-1.02318
#  1st Qu.:-0.62335   1st Qu.:-0.64322   1st Qu.:-0.64808   1st Qu.:-0.68171
#  Median :-0.24657   Median :-0.26237   Median :-0.25702   Median :-0.42727
#  Mean   : 0.04122   Mean   : 0.04788   Mean   : 0.03803   Mean   :-0.05914
#  3rd Qu.: 0.31855   3rd Qu.: 0.44398   3rd Qu.: 0.43108   3rd Qu.: 0.18191
#  Max.   : 5.08073   Max.   : 7.12475   Max.   : 6.91164   Max.   : 5.20005
#   Feature 53        Feature 54         Feature 55         Feature 56
#  Min.   :-1.7899   Min.   :-2.67825   Min.   :-2.46287   Min.   :-2.535428
#  1st Qu.:-0.7831   1st Qu.:-0.61827   1st Qu.:-0.29880   1st Qu.:-0.699089
#  Median : 0.1286   Median :-0.19399   Median :-0.06183   Median :-0.005262
#  Mean   :-0.0808   Mean   :-0.03658   Mean   : 0.01065   Mean   : 0.004306
#  3rd Qu.: 0.3807   3rd Qu.: 0.51551   3rd Qu.: 0.17430   3rd Qu.: 0.720398
#  Max.   : 4.7189   Max.   : 2.84802   Max.   :12.71590   Max.   : 4.774770
#   Feature 57          Feature 58          Feature 59         Feature 60
#  Min.   :-2.208065   Min.   :-1.702372   Min.   :-1.46694   Min.   :-1.66511
#  1st Qu.:-0.722532   1st Qu.:-0.722763   1st Qu.:-0.71716   1st Qu.:-0.72907
#  Median :-0.106788   Median :-0.158718   Median :-0.25433   Median :-0.21779
#  Mean   :-0.006111   Mean   : 0.003739   Mean   : 0.01855   Mean   : 0.03884
#  3rd Qu.: 0.561764   3rd Qu.: 0.553896   3rd Qu.: 0.47132   3rd Qu.: 0.58520
#  Max.   : 4.868598   Max.   : 4.952606   Max.   : 5.03054   Max.   : 4.75189
#   Feature 61         Feature 62         Feature 63         Feature 64
#  Min.   :-1.59751   Min.   :-1.57965   Min.   :-1.61437   Min.   :-1.50595
#  1st Qu.:-0.65656   1st Qu.:-0.67876   1st Qu.:-0.67489   1st Qu.:-0.66035
#  Median :-0.19321   Median :-0.17159   Median :-0.16593   Median :-0.19318
#  Mean   : 0.03599   Mean   : 0.03443   Mean   : 0.03451   Mean   : 0.02823
#  3rd Qu.: 0.47344   3rd Qu.: 0.50877   3rd Qu.: 0.48859   3rd Qu.: 0.47457
#  Max.   : 7.39726   Max.   : 5.33684   Max.   : 8.32957   Max.   : 5.85470
#   Feature 65         Feature 66         Feature 67         Feature 68
#  Min.   :-1.40477   Min.   :-1.24870   Min.   :-1.22159   Min.   :-1.3296
#  1st Qu.:-0.69102   1st Qu.:-0.64985   1st Qu.:-0.64026   1st Qu.:-0.6559
#  Median :-0.22812   Median :-0.25069   Median :-0.31488   Median :-0.2970
#  Mean   : 0.04148   Mean   : 0.03283   Mean   : 0.03697   Mean   : 0.0339
#  3rd Qu.: 0.51228   3rd Qu.: 0.34853   3rd Qu.: 0.44571   3rd Qu.: 0.3719
#  Max.   : 5.44233   Max.   : 6.43785   Max.   : 5.38736   Max.   : 5.9772
#    Country
#  Length:1002
#  Class :character
#  Mode  :character
